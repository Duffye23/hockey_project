# %%
import tensorflow as tf
import pandas as pd
import random
from tensorflow.keras.models import load_model
from tensorflow_addons.metrics import RSquare

# %%
players_df_new = pd.read_csv("data/model_2023-2024.csv")
name = players_df_new['name']
players_df_new.head()
# Out:
#    Unnamed: 0             name  minutes/game  I_F_xOnGoal  I_F_xGoals  \
# 0           0     Kaiden Guhle     20.611429        46.90        2.34
# 1           1     Curtis Lazar     12.498990        33.72        3.31
# 2           2  Ilya Lyubushkin     17.219231        30.62        1.85
# 3           3      Josh Norris     18.541146        80.33        9.23
# 4           4      Brett Kulak     14.787037        38.71        1.71
#
#    I_F_xRebounds  I_F_shotAttempts  I_F_points  I_F_rebounds  I_F_takeaways  \
# 0           2.77               102          10             2             12
# 1           2.27                61          13             2             10
# 2           1.71                64           4             2             14
# 3           5.35               147          20             5             11
# 4           2.00                88           4             2              7
#
#    ...  I_F_lowDangerShots  I_F_mediumDangerShots  I_F_highDangerShots  \
# 0  ...                  61                      5                    1
# 1  ...                  33                      9                    4
# 2  ...                  38                      4                    1
# 3  ...                  71                     28                    9
# 4  ...                  52                      1                    2
#
#    I_F_lowDangerxGoals  I_F_mediumDangerxGoals  I_F_highDangerxGoals  \
# 0                 1.39                    0.65                  0.31
# 1                 0.99                    1.21                  1.11
# 2                 0.90                    0.56                  0.40
# 3                 2.21                    3.30                  3.73
# 4                 1.17                    0.10                  0.44
#
#    I_F_lowDangerGoals  I_F_mediumDangerGoals  I_F_highDangerGoals  \
# 0                   1                      1                    1
# 1                   2                      0                    2
# 2                   0                      0                    0
# 3                   1                      6                    5
# 4                   2                      0                    0
#
#    I_F_unblockedShotAttempts
# 0                         67
# 1                         46
# 2                         43
# 3                        108
# 4                         55
#
# [5 rows x 21 columns]

# %%
players_df_new.drop(['Unnamed: 0','name'], axis='columns',inplace=True)
players_df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 811 entries, 0 to 810
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   minutes/game               811 non-null    float64
#  1   I_F_xOnGoal                811 non-null    float64
#  2   I_F_xGoals                 811 non-null    float64
#  3   I_F_xRebounds              811 non-null    float64
#  4   I_F_shotAttempts           811 non-null    int64
#  5   I_F_points                 811 non-null    int64
#  6   I_F_rebounds               811 non-null    int64
#  7   I_F_takeaways              811 non-null    int64
#  8   I_F_giveaways              811 non-null    int64
#  9   I_F_lowDangerShots         811 non-null    int64
#  10  I_F_mediumDangerShots      811 non-null    int64
#  11  I_F_highDangerShots        811 non-null    int64
#  12  I_F_lowDangerxGoals        811 non-null    float64
#  13  I_F_mediumDangerxGoals     811 non-null    float64
#  14  I_F_highDangerxGoals       811 non-null    float64
#  15  I_F_lowDangerGoals         811 non-null    int64
#  16  I_F_mediumDangerGoals      811 non-null    int64
#  17  I_F_highDangerGoals        811 non-null    int64
#  18  I_F_unblockedShotAttempts  811 non-null    int64
# dtypes: float64(7), int64(12)
# memory usage: 120.5 KB

# %%
nn = load_model('points_predictor_nn.h5')

nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 95
#
#  dense_1 (Dense)             (None, 5)                 30
#
#  dense_2 (Dense)             (None, 5)                 30
#
#  dense_3 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 161
# Trainable params: 161
# Non-trainable params: 0
# _________________________________________________________________

# %%
y = players_df_new.I_F_points.values
X = players_df_new.drop(columns='I_F_points').values

# %%
model_loss, model_accuracy = nn.evaluate(X ,y ,verbose=2)
print(f"Loss: {model_loss}, R-Square: {model_accuracy}")
# Out:
# 26/26 - 2s - loss: 20.1168 - r_square: 0.8577 - 2s/epoch - 65ms/step
# Loss: 20.116777420043945, R-Square: 0.8577220439910889

# %%
prediction = nn.predict(X)

picked_player = random.randint(0,810)

print('Name:',name[picked_player])
print('Predicted Points:',prediction[picked_player])
print('Actual Points:',players_df_new.I_F_points[picked_player])
# Out:
# 26/26 [==============================] - 0s 2ms/step
# Name: Ethan Bear
# Predicted Points: [2.0658607]
# Actual Points: 1
