# %%
#import dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

#import and read cleaned_2022
import pandas as pd
players_df1 = pd.read_csv("model_2022-2023.csv")
players_df1.head()
# Out:
#    Unnamed: 0 position  games_played  minutes/game  I_F_xOnGoal  I_F_xGoals  \
# 0           0        R            73          9.32        49.47        6.70
# 1           1        D            68         15.01        37.10        1.36
# 2           2        D            61         13.04        69.79        2.44
# 3           3        D            42         14.02        32.17        1.21
# 4           4        C            28         16.00        39.69        6.81
#
#    I_F_xRebounds  I_F_primaryAssists  I_F_secondaryAssists  I_F_shotAttempts  \
# 0           3.80                   5                     5                79
# 1           1.83                   6                     6                78
# 2           3.85                   1                     2               140
# 3           1.81                   2                     4                79
# 4           2.85                   5                     4                65
#
# ...

# %%
# players_df.drop(['Unnamed: 0', 'position', 'Line_or_Pair',], axis='columns',inplace=True)
# players_df.head()

# %%
players_df = players_df1[['I_F_goals', 'I_F_points']]

# %%
players_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 774 entries, 0 to 773
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   I_F_goals   774 non-null    int64
#  1   I_F_points  774 non-null    int64
# dtypes: int64(2)
# memory usage: 12.2 KB

# %%
#value count the I_F_points column to see if we need to bin the data
points_count = players_df['I_F_points'].value_counts()
points_count
# Out:
# 3      26
# 1      24
# 14     24
# 8      23
# 16     22
#        ..
# 85      1
# 84      1
# 71      1
# 77      1
# 153     1
# Name: I_F_points, Length: 102, dtype: int64

# %%
# #convert categorical data into numeric with 'get_dummies'
# players_df = pd.get_dummies(players_df)
# players_df.head()

# %%
#split data into features and target arrays
y = players_df.I_F_points.values
X = players_df.drop(columns='I_F_points').values

#split data into training and testing datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
#create standardscaler instance
scaler = StandardScaler()

#fit the standardscaler
X_scaler = scaler.fit(X_train)

#scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=1000, activation="relu", input_dim=number_input_features))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=1000, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="relu"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 1000)              2000
#
#  dense_1 (Dense)             (None, 1000)              1001000
#
#  dense_2 (Dense)             (None, 1)                 1001
#
# ...
# Total params: 1,004,001
# Trainable params: 1,004,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
# fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
fit_model = nn.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 19/19 [==============================] - 1s 7ms/step - loss: 437.1111 - accuracy: 0.0121
# Epoch 2/100
# 19/19 [==============================] - 0s 7ms/step - loss: 437.1111 - accuracy: 0.0121
# Epoch 3/100
# 19/19 [==============================] - 0s 7ms/step - loss: 437.1111 - accuracy: 0.0121
# Epoch 4/100
# 19/19 [==============================] - 0s 7ms/step - loss: 437.1111 - accuracy: 0.0121
# Epoch 5/100
# 19/19 [==============================] - 0s 8ms/step - loss: 437.1111 - accuracy: 0.0121
# Epoch 6/100
# 19/19 [==============================] - 0s 8ms/step - loss: 437.1111 - accuracy: 0.0121
# Epoch 7/100
# 19/19 [==============================] - 0s 8ms/step - loss: 437.1111 - accuracy: 0.0121
# Epoch 8/100
# 19/19 [==============================] - 0s 8ms/step - loss: 437.1111 - accuracy: 0.0121
# Epoch 9/100
# 19/19 [==============================] - 0s 8ms/step - loss: 437.1111 - accuracy: 0.0121
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
# model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
model_loss, model_accuracy = nn.evaluate(X_test,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 7/7 - 0s - loss: 442.7119 - accuracy: 0.0103 - 96ms/epoch - 14ms/step
# Loss: 442.7119140625, Accuracy: 0.010309278033673763
