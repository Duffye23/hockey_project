# %%
#import dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import jenkspy

#import and read cleaned_2022
import pandas as pd
players_df = pd.read_csv("model_2022-2023.csv")
players_df.head()
# Out:
#    Unnamed: 0  Unnamed: 1 position  games_played  icetime  minutes/game  \
# 0           0           0        R            73    40825          9.32
# 1           1           1        D            68    61236         15.01
# 2           2           2        D            61    47720         13.04
# 3           3           3        D            42    35331         14.02
# 4           4           4        C            28    26877         16.00
#
#    onIce_xGoalsPercentage  onIce_corsiPercentage  onIce_fenwickPercentage  \
# 0                    0.45                   0.45                     0.46
# 1                    0.39                   0.42                     0.41
# 2                    0.44                   0.45                     0.46
# 3                    0.56                   0.53                     0.52
# 4                    0.52                   0.46                     0.46
#
#    iceTimeRank  ...  OnIce_A_scoreAdjustedShotsAttempts  \
# 0          814  ...                              674.73
# 1          329  ...                             1104.67
# 2          338  ...                              791.60
# 3          242  ...                              508.74
# 4          139  ...                              425.03
#
#    OnIce_A_unblockedShotAttempts  OnIce_A_scoreAdjustedUnblockedShotAttempts  \
# 0                            491                                      489.13
# 1                            863                                      864.75
# 2                            562                                      565.64
# 3                            378                                      379.33
# 4                            316                                      313.93
#
#    OnIce_A_xGoalsFromxReboundsOfShots  \
# 0                                4.67
# 1                               10.65
# 2                                5.69
# 3                                3.76
# 4                                3.19
#
#    OnIce_A_xGoalsFromActualReboundsOfShots  OnIce_A_reboundxGoals  \
# 0                                     6.20                   6.20
# 1                                    15.01                  14.72
# 2                                     5.62                   5.62
# 3                                     7.03                   7.03
# 4                                     2.47                   2.47
#
#    OnIce_A_xGoals_with_earned_rebounds  \
# 0                                27.06
# 1                                62.63
# 2                                34.16
# 3                                21.02
# 4                                20.77
#
#    OnIce_A_xGoals_with_earned_rebounds_scoreAdjusted  \
# 0                                              26.92
# 1                                              62.82
# 2                                              34.30
# 3                                              21.10
# 4                                              20.86
#
#    OnIce_A_xGoals_with_earned_rebounds_scoreFlurryAdjusted  Line_or_Pair
# 0                                              26.43            3rd line
# 1                                              60.81            3rd pair
# 2                                              33.73            3rd pair
# 3                                              20.84            3rd pair
# 4                                              20.65            2nd line
#
# [5 rows x 137 columns]

# %%
#drop unnamed columns
players_df.drop(['Unnamed: 0', 'Unnamed: 1'], axis='columns', inplace=True)
players_df.head()
# Out:
#   position  games_played  icetime  minutes/game  onIce_xGoalsPercentage  \
# 0        R            73    40825          9.32                    0.45
# 1        D            68    61236         15.01                    0.39
# 2        D            61    47720         13.04                    0.44
# 3        D            42    35331         14.02                    0.56
# 4        C            28    26877         16.00                    0.52
#
#    onIce_corsiPercentage  onIce_fenwickPercentage  iceTimeRank  I_F_xOnGoal  \
# 0                   0.45                     0.46          814        49.47
# 1                   0.42                     0.41          329        37.10
# 2                   0.45                     0.46          338        69.79
# 3                   0.53                     0.52          242        32.17
# 4                   0.46                     0.46          139        39.69
#
#    I_F_xGoals  ...  OnIce_A_scoreAdjustedShotsAttempts  \
# 0        6.70  ...                              674.73
# 1        1.36  ...                             1104.67
# 2        2.44  ...                              791.60
# 3        1.21  ...                              508.74
# 4        6.81  ...                              425.03
#
#    OnIce_A_unblockedShotAttempts  OnIce_A_scoreAdjustedUnblockedShotAttempts  \
# 0                            491                                      489.13
# 1                            863                                      864.75
# 2                            562                                      565.64
# 3                            378                                      379.33
# 4                            316                                      313.93
#
#    OnIce_A_xGoalsFromxReboundsOfShots  \
# 0                                4.67
# 1                               10.65
# 2                                5.69
# 3                                3.76
# 4                                3.19
#
#    OnIce_A_xGoalsFromActualReboundsOfShots  OnIce_A_reboundxGoals  \
# 0                                     6.20                   6.20
# 1                                    15.01                  14.72
# 2                                     5.62                   5.62
# 3                                     7.03                   7.03
# 4                                     2.47                   2.47
#
#    OnIce_A_xGoals_with_earned_rebounds  \
# 0                                27.06
# 1                                62.63
# 2                                34.16
# 3                                21.02
# 4                                20.77
#
#    OnIce_A_xGoals_with_earned_rebounds_scoreAdjusted  \
# 0                                              26.92
# 1                                              62.82
# 2                                              34.30
# 3                                              21.10
# 4                                              20.86
#
#    OnIce_A_xGoals_with_earned_rebounds_scoreFlurryAdjusted  Line_or_Pair
# 0                                              26.43            3rd line
# 1                                              60.81            3rd pair
# 2                                              33.73            3rd pair
# 3                                              20.84            3rd pair
# 4                                              20.65            2nd line
#
# [5 rows x 135 columns]

# %%
#value count the I_F_points column to see if we need to bin the data
points_count = players_df['I_F_points'].value_counts()
points_count
# Out:
# 3      26
# 1      24
# 14     24
# 8      23
# 16     22
#        ..
# 85      1
# 84      1
# 71      1
# 77      1
# 153     1
# Name: I_F_points, Length: 102, dtype: int64

# %%
#use jenks_breaks to find the natural breaks in the data, these breaks will become our bin values
point_breaks = jenkspy.jenks_breaks(players_df['I_F_points'], n_classes=10)
point_breaks
# Out:
# [0, 7, 15, 24, 34, 46, 58, 70, 87, 113, 153]

# %%
#create function to cycle through the data and place them in the bins defined in the previous step
def point_bucket(column):
    if column['I_F_points'] < 7:
        return 0.1
    elif column['I_F_points'] < 15:
        return 0.2
    elif column['I_F_points'] < 24:
        return 0.3
    elif column['I_F_points'] < 34:
        return 0.4
    elif column['I_F_points'] < 46:
        return 0.5
    elif column['I_F_points'] < 58:
        return 0.6
    elif column['I_F_points'] < 70:
        return 0.7
    elif column['I_F_points'] < 87:
        return 0.8
    elif column['I_F_points'] < 113:
        return 0.9
    else:
        return 1
    

# Apply the function to create the new column
players_df['point_bucket'] = players_df.apply(point_bucket, axis=1)

#value count to see the distribution of the data in your bins
players_df['point_bucket'].value_counts()
# Out:
# 0.3    142
# 0.2    137
# 0.1    129
# 0.4    116
# 0.5     97
# 0.6     53
# 0.8     40
# 0.7     40
# 0.9     16
# 1.0      4
# Name: point_bucket, dtype: int64

# %%
players_df.drop(['I_F_points'], axis='columns', inplace=True)
players_df.head()
# Out:
#   position  games_played  icetime  minutes/game  onIce_xGoalsPercentage  \
# 0        R            73    40825          9.32                    0.45
# 1        D            68    61236         15.01                    0.39
# 2        D            61    47720         13.04                    0.44
# 3        D            42    35331         14.02                    0.56
# 4        C            28    26877         16.00                    0.52
#
#    onIce_corsiPercentage  onIce_fenwickPercentage  iceTimeRank  I_F_xOnGoal  \
# 0                   0.45                     0.46          814        49.47
# 1                   0.42                     0.41          329        37.10
# 2                   0.45                     0.46          338        69.79
# 3                   0.53                     0.52          242        32.17
# 4                   0.46                     0.46          139        39.69
#
#    I_F_xGoals  ...  OnIce_A_unblockedShotAttempts  \
# 0        6.70  ...                            491
# 1        1.36  ...                            863
# 2        2.44  ...                            562
# 3        1.21  ...                            378
# 4        6.81  ...                            316
#
#    OnIce_A_scoreAdjustedUnblockedShotAttempts  \
# 0                                      489.13
# 1                                      864.75
# 2                                      565.64
# 3                                      379.33
# 4                                      313.93
#
#    OnIce_A_xGoalsFromxReboundsOfShots  \
# 0                                4.67
# 1                               10.65
# 2                                5.69
# 3                                3.76
# 4                                3.19
#
#    OnIce_A_xGoalsFromActualReboundsOfShots  OnIce_A_reboundxGoals  \
# 0                                     6.20                   6.20
# 1                                    15.01                  14.72
# 2                                     5.62                   5.62
# 3                                     7.03                   7.03
# 4                                     2.47                   2.47
#
#    OnIce_A_xGoals_with_earned_rebounds  \
# 0                                27.06
# 1                                62.63
# 2                                34.16
# 3                                21.02
# 4                                20.77
#
#    OnIce_A_xGoals_with_earned_rebounds_scoreAdjusted  \
# 0                                              26.92
# 1                                              62.82
# 2                                              34.30
# 3                                              21.10
# 4                                              20.86
#
#    OnIce_A_xGoals_with_earned_rebounds_scoreFlurryAdjusted  Line_or_Pair  \
# 0                                              26.43            3rd line
# 1                                              60.81            3rd pair
# 2                                              33.73            3rd pair
# 3                                              20.84            3rd pair
# 4                                              20.65            2nd line
#
#    point_bucket
# 0           0.3
# 1           0.2
# 2           0.1
# 3           0.2
# 4           0.3
#
# [5 rows x 135 columns]

# %%
#convert categorical data into numeric with 'get_dummies'
players_df = pd.get_dummies(players_df)
players_df.head()
# Out:
#    games_played  icetime  minutes/game  onIce_xGoalsPercentage  \
# 0            73    40825          9.32                    0.45
# 1            68    61236         15.01                    0.39
# 2            61    47720         13.04                    0.44
# 3            42    35331         14.02                    0.56
# 4            28    26877         16.00                    0.52
#
#    onIce_corsiPercentage  onIce_fenwickPercentage  iceTimeRank  I_F_xOnGoal  \
# 0                   0.45                     0.46          814        49.47
# 1                   0.42                     0.41          329        37.10
# 2                   0.45                     0.46          338        69.79
# 3                   0.53                     0.52          242        32.17
# 4                   0.46                     0.46          139        39.69
#
#    I_F_xGoals  I_F_xRebounds  ...  position_C  position_D  position_L  \
# 0        6.70           3.80  ...           0           0           0
# 1        1.36           1.83  ...           0           1           0
# 2        2.44           3.85  ...           0           1           0
# 3        1.21           1.81  ...           0           1           0
# 4        6.81           2.85  ...           1           0           0
#
#    position_R  Line_or_Pair_1st line  Line_or_Pair_1st pair  \
# 0           1                      0                      0
# 1           0                      0                      0
# 2           0                      0                      0
# 3           0                      0                      0
# 4           0                      0                      0
#
#    Line_or_Pair_2nd line  Line_or_Pair_2nd pair  Line_or_Pair_3rd line  \
# 0                      0                      0                      1
# 1                      0                      0                      0
# 2                      0                      0                      0
# 3                      0                      0                      0
# 4                      1                      0                      0
#
#    Line_or_Pair_3rd pair
# 0                      0
# 1                      1
# 2                      1
# 3                      1
# 4                      0
#
# [5 rows x 143 columns]

# %%
#split data into features and target arrays
y = players_df.point_bucket.values
X = players_df.drop(columns='point_bucket').values

#split data into training and testing datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
#create standardscaler instance
scaler = StandardScaler()

#fit the standardscaler
X_scaler = scaler.fit(X_train)

#scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=20, activation="relu", input_dim=number_input_features))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=20, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=20, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=20, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=20, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=20, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                2860
#
#  dense_1 (Dense)             (None, 20)                420
#
#  dense_2 (Dense)             (None, 20)                420
#
#  dense_3 (Dense)             (None, 20)                420
#
#  dense_4 (Dense)             (None, 20)                420
#
#  dense_5 (Dense)             (None, 20)                420
#
#  dense_6 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: